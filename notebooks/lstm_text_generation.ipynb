# %% [markdown]
# # Shakespeare Word-Level LSTM Text Generation
# Interview assessment — TensorFlow/Keras + Shakespeare + word-level next-token prediction.

# %%
# !pip -q install -r requirements.txt
import tensorflow as tf
print('TensorFlow:', tf.__version__)
print('GPU:', tf.config.list_physical_devices('GPU'))

# %%
from src.train import main
main()

# %%
from src.generate import main
import sys
sys.argv = ['generate.py', '--seed', 'to be or not to be', '--words', '40', '--temperature', '0.8']
main()

# %% [markdown]
# ## Optional bonus experiment
# Run this only if time remains. It compares a 1-layer/20-token baseline with a 2-layer/40-token model using a smaller quick-run dataset.

# %%
from src.experiment import main
main()
